# %% [markdown]
# # Crawling Web Berita CNN Indonesia

# %% [markdown]
# ## Apa itu Crawling?

# %% [markdown]
# Crawling merupakan proses search engine untuk menemukan konten atau sesuatu situs halaman yang ada. Dalam bahasa kerennya crawling atau web crawling merupakan proses dimana search engine mengirimkan bot atau robot yang disebut (crawler atau spider) yang digunakan untuk menemukan konten-konten yang ada.
#
# Yang dimaksud konten yaitu bervariasi, mulai dari halaman website yang saya lakukan ini, kemudian gambar, video, dokumen, dan lain sebagainya. Seperti halnya laba-laba, datang ke sebuah jaring dan melihat beberapa halaman website, kemudian mengikuti link yang terdapat di halaman website tersebut untuk mencari URL yang baru.
#
# Ketika ada pengguna yang mencari sebuah konten di search engine dengan keyword tertentu, search engine akan mencarinya di indeks dan menentukan konten mana yang paling sesuai untuk pengguna tersebut.

# %% [markdown]
# ## Proses Crawling

# %% [markdown]
# ### Tool atau Library

# %%
# Import Library yang dibutuhkan
import requests as req
from bs4 import BeautifulSoup as bs
import time
import pandas as pd

# %% [markdown]
# * **Request** digunakan untuk mengambil html/http dari sebuah website.
# * **BeautifulSoup** berfungsi untuk mengambil data dari html/xml.
# * **Time** berfungsi untuk memberikan jeda ketika ingin berpindah halaman.
# * **Pandas** digunakan untuk membuat dataframe agar mudah dibaca.

# %% [markdown]
# ### Code Program

# %% [markdown]
# #### Fungsi Clean_text()

# %%
def clean_text(text):
    text = text.replace('\xa0', '')
    text = text.replace('ADVERTISEMENT', '')
    text = text.replace('SCROLL TO CONTINUE WITH CONTENT', '')
    text = text.replace('\n', '')
    return text.strip()

# %% [markdown]
# Fungsi untuk membersihkan text yang tidak diinginkan, atau mengganggu.

# %% [markdown]
# #### Fungsi scrape_news()

# %%
def scrape_news(soup):
    berita = {}
    texts = []
    
    berita["judul"] = soup.title.text
    
    text_list = soup.find("div", class_="detail-text text-cnn_black text-sm grow min-w-0")
    berita["isi"] = text_list.find_all("p")
    for text in text_list.find_all("p"):
        cleaned_text = clean_text(text.text)
        texts.append(cleaned_text)
        
    berita["isi"] = " ".join(texts)
    berita["tanggal"] = soup.find("div", class_="container !w-[1100px] overscroll-none").find_all("div")[1].find_all("div")[4].text
    berita["kategori"] = soup.find("a", attrs={"aria-label": "link description", "dtr-act": "kanal"}).text
    return berita

# %% [markdown]
# Pada fungsi ini berisikan proses pembedahan dan juga pengambilan data pada sebuah website. Mengambil data sesuai struktur HTML/web yang ingin diambil datanya.

# %% [markdown]
# #### Fungsi get_html()

# %%
def get_html(url):
    try:
        response = req.get(url).text
        return bs(response, "html5lib")
    
    except Exception as e:
        print(e)
        return ""

# %% [markdown]
# Fungsi get_html dengan parameter url digunakan untuk mengambil response atau isi html dari web. Untuk mengambil response tersebut dibutuhkan library request, dan juga BeautifulSoup untuk mendapatkan isi html.

# %% [markdown]
# #### Fungsi get_news()

# %%
def get_news(soup):
    container = soup.find("div", class_="container !w-[1100px] overscroll-none")
    news_list = container.find_all("article", class_="flex-grow")
    return news_list

# %% [markdown]
# Fungsi get_news berfungsi untuk mengambil semua berita yang ada pada web, yang kemudian didapat kumpulan url berita yang ada pada halaman web.

# %% [markdown]
# #### Main Crawling

# %%
def main(halaman=1):
	url = "https://www.cnnindonesia.com/indeks/2/"
	news = []
	count = 1 # - n

	for counter in range(halaman):
		page = url + str(count)    
		soup = get_html(page)
		news_list = get_news(soup)
		
		for item in news_list:
			news_url = item.find('a')['href']
			# print(news_url)
			soup_news = get_html(news_url)
			result = scrape_news(soup_news)
			news.append(result)
		
		count+=1
		time.sleep(1)
		
	return news

# %% [markdown]
# Menyiapkan link/base url web berita yang ingin dicrawling, terdapat beberapa fungsi yang dipanggil yang sudah dibuat sebelumnya untuk mengambil informasi atau berita pada halaman website. Dalam code tersebut terdapat beberapa tahapan seperti fungsi:
# * get_html
# * get_news
# * scrape_news

# %% [markdown]
# #### Main

# %%
halaman = int(input('Crawling berapa Halaman? '))
news = main(halaman)

# %% [markdown]
# Menjalankan program yang sudah dibuat dengan input berapa halaman yang ingin diambil.

# %% [markdown]
# ### Convert Dataframe

# %%
df = pd.DataFrame.from_dict(news)
df
# Out:
#                                                 judul  \
# 0   Alat Skrining Virus Mpox Dipasang di Bandara S...
# 1   Indonesia Pastikan Emas di Ganda Campuran Badm...
# 2   Rano Karno Puji Anies Saat Bertemu di CFD Jakarta
# 3   FOTO: Terbang dan Menekan, Leo/Bagas Juara Kor...
# 4   Borong, Mangga Harum Manis Diskon 20% di Trans...
# 5   BRI Berhasil Raih Predikat Diamond di Ajang Se...
# 6            Prediksi MU vs Liverpool di Liga Inggris
# 7     Kok Bisa Harga BBM Pertamina Non Subsidi Turun?
# 8   Warga Pulau Rempang Diteror, Spanduk Tolak PSN...
# 9   Kata-kata Leo/Bagas Usai Raih Gelar Pertama di...
# 10  Kata-kata Leo/Bagas Usai Raih Gelar Pertama di...
# 11                  Lirik Lagu Nasional Pada Pahlawan
# 12  2 Megathrust Bikin Khawatir BPBD Bogor hingga ...
# 13  BRI Dorong UMKM Kerajinan dan Seni Kriya Naik ...
# 14  Beli Sepeda Listrik di Transmart, Diskonnya Bi...
# 15  Netizen Heboh Usai Leo/Bagas Juara Korea Open ...
# 16  Pengamat Nilai PDIP Bakal Kerja Ekstra Keras u...
# 17  Kiper Timnas Indonesia Dikaruniai Anak Kedua J...
# 18  Penjelasan Ending dan Post-Credit Scene Blue L...
# 19  AC 1 PK di Transmart Rp3 Jutaan Aja, Sudah Bon...
# 20       Bagas Gendong Leo Usai Juara Korea Open 2024
# 21  Sinopsis Kaka Boss, Mimpi Bos Penagih Utang Ja...
# 22                    Leo/Bagas Juara Korea Open 2024
# 23  Tanggal Muda Beli Sepeda di Transmart, Diobral...
# 24  'No Sugar Diet', Benarkah Tak Boleh Ada Gula S...
# 25  Pemerintah Jamin Pertalite Tak Dihapus, Cuma J...
# 26  Yolla Yuliana Resmi Gabung Klub Voli Jepang To...
# 27  FOTO: Saling Puji Jokowi-Prabowo Kala Penutupa...
# 28  FOTO: Dharma-Kun Jalani Tes Kesehatan di RSUD ...
# 29  Transmart Full Day Sale, Kulkas SBS Banting Ha...
# 30  Awal Bulan Merapat ke Transmart Full Day Sale,...
# 31  Mengenal Bentuk-Ciri Investasi Bodong Berkaca ...
# 32  Alasan dan Arti Gelar Ali bin Abi Thalib 'Karr...
# 33  Megathrust Mengancam, Bogor Keluarkan Edaran P...
# 34   3 Manfaat Memanaskan Mesin Motor Sebelum Dipakai
# 35  Hasil MLS: Maarten Paes Main, Dallas Kalah Dra...
# 36  Restoran di Terminal 3 Soetta Kebakaran, Pener...
# 37  Pahami Sanksi Bawa Barang dari Luar Negeri Tak...
# 38  INFOGRAFIS: 5 Jenis Minyak yang Tak Sehat Buat...
# 39  Rapor Indra Sjafri Pimpin Timnas Indonesia vs ...
# 40  Hasil MLS: Maarten Paes Main, Dallas Kalah Dra...
# 41  Restoran di Terminal 3 Soetta Kebakaran, Pener...
# 42  Pahami Sanksi Bawa Barang dari Luar Negeri Tak...
# 43  INFOGRAFIS: 5 Jenis Minyak yang Tak Sehat Buat...
# 44  Rapor Indra Sjafri Pimpin Timnas Indonesia vs ...
# 45  Mark Mateschitz, Sang Pewaris 'Red Bull' Berha...
# 46  Rekayasa Lalu Lintas saat Kunjungan Paus Frans...
# 47  FOTO: Panasnya Perang Lawan Nyamuk di Perbatas...
# 48  Yuk Borong, Minyak Goreng sampai Detergen Lebi...
# 49     Daftar BBM Pertamina yang Turun Harga Hari Ini
#
#                                                   isi  \
# 0   PT Angkasa Pura II (Persero), selaku pengelola...
# 1   Kontingen Indonesia memastikan medali emas di ...
# 2   Calon Wakil Gubernur DKI Jakarta, Rano Karno m...
# 3
# 4   Mau beli mangga manis dan segar, harganya disk...
# 5   PT Bank Rakyat Indonesia (Pesero) Tbk atau BRI...
# 6   Manchester Unitedakan menjamuLiverpool pada pe...
# 7   Per 1 September 2024 harga BBMPertaminanonsubs...
# 8   Warga di Pulau Rempang,Kelurahan Sembulang Kec...
# 9   Ganda putra Indonesia Leo Rolly Carnando/Bagas...
# 10  Ganda putra Indonesia Leo Rolly Carnando/Bagas...
# 11  Lirik lagu Pada Pahlawan menggambarkan rasa te...
# 12  Badan Penanggulangan Bencana Daerah (BPBD) Kot...
# 13  Pameran kerajinan dan seni kriya berskala nasi...
# 14  Transmart Full Day Sale kembali lagi dengan di...
# 15  Netizen bereaksi setelah pasangan baru ganda p...
# 16  PDIPsecara mengejutkanmengusung bapaslonJeje W...
# 17  Istri kiperTimnas Indonesia Muhammad Adi Satry...
# 18  Blue Lock: Episode Nagitayang di bioskop Indon...
# 19  Transmart Full Day Sale balik lagi hari ini, M...
# 20  Leo Rolly Carnando langsung melompat dan digen...
# 21  Kaka Bossmenjadi film komedi Indonesia terbaru...
# 22  Ganda putra Indonesia Leo Rolly Carnando/Bagas...
# 23  Transmart Full Day Sale kembali lagi hari ini,...
# 24  No sugar diet akhir-akhir ini jadi tren para p...
# 25  Wakil Menteri BUMN Kartika Wirjoatmodjo memban...
# 26  Bintang voli putri Indonesia Yolla Yulianaresm...
# 27
# 28
# 29  Transmart Full Day Sale datang lagi dengan dis...
# 30  Awal bulan waktunya merapat keTransmartFull Da...
# 31  Kasusinvestasi bodong kian marak dari hari ke ...
# 32  Ali bin Abi Thalibmempunyai gelar atau julukan...
# 33  Badan Penanggulangan Bencana Daerah (BPBD) Kot...
# 34  Memanaskanmesin sepeda motor injeksi sebelum d...
# 35  KiperTimnas IndonesiaMaarten Paestampil sebaga...
# 36  Salah satu tenant makanan di Terminal 3 Bandar...
# 37  Membawa barang bawaan dari luar negeri tanpa l...
# 38  Banyak jenis minyak yang digunakan untuk memas...
# 39  PelatihTimnas Indonesia U-20 Indra Sjafrisudah...
# 40  KiperTimnas IndonesiaMaarten Paestampil sebaga...
# 41  Salah satu tenant makanan di Terminal 3 Bandar...
# 42  Membawa barang bawaan dari luar negeri tanpa l...
# 43  Banyak jenis minyak yang digunakan untuk memas...
# 44  PelatihTimnas Indonesia U-20 Indra Sjafrisudah...
# 45  Mark Mateschitzadalah konglomerat asal Austria...
# 46  Rekayasa lalu lintas akan diberlakukan sehubun...
# 47
# 48  Habis gajian waktunya kembali mengisi keperlua...
# 49  PT Pertamina(Persero) melalui anak usahanya PT...
#
#                             tanggal    kategori
# 0    Minggu, 01 Sep 2024 14:29 WIB     Nasional
# 1    Minggu, 01 Sep 2024 14:27 WIB     Olahraga
# 2    Minggu, 01 Sep 2024 14:19 WIB     Nasional
# 3     Minggu, 01 Sep 2024 14:10 WIB    Olahraga
# 4    Minggu, 01 Sep 2024 14:00 WIB      Ekonomi
# 5    Minggu, 01 Sep 2024 13:52 WIB      Ekonomi
# 6    Minggu, 01 Sep 2024 13:47 WIB     Olahraga
# 7    Minggu, 01 Sep 2024 13:37 WIB      Ekonomi
# 8    Minggu, 01 Sep 2024 13:20 WIB     Nasional
# 9    Minggu, 01 Sep 2024 13:12 WIB     Olahraga
# 10   Minggu, 01 Sep 2024 13:12 WIB     Olahraga
# 11   Minggu, 01 Sep 2024 13:10 WIB      Edukasi
# 12   Minggu, 01 Sep 2024 13:08 WIB    Teknologi
# 13   Minggu, 01 Sep 2024 13:01 WIB      Ekonomi
# 14   Minggu, 01 Sep 2024 13:00 WIB      Ekonomi
# 15   Minggu, 01 Sep 2024 12:48 WIB     Olahraga
# 16   Minggu, 01 Sep 2024 12:41 WIB     Nasional
# 17   Minggu, 01 Sep 2024 12:16 WIB     Olahraga
# 18   Minggu, 01 Sep 2024 12:06 WIB      Hiburan
# 19   Minggu, 01 Sep 2024 12:00 WIB      Ekonomi
# 20   Minggu, 01 Sep 2024 11:45 WIB     Olahraga
# 21   Minggu, 01 Sep 2024 11:35 WIB      Hiburan
# 22   Minggu, 01 Sep 2024 11:17 WIB     Olahraga
# 23   Minggu, 01 Sep 2024 11:15 WIB      Ekonomi
# 24   Minggu, 01 Sep 2024 11:09 WIB   Gaya Hidup
# 25   Minggu, 01 Sep 2024 11:00 WIB      Ekonomi
# 26   Minggu, 01 Sep 2024 10:52 WIB     Olahraga
# 27    Minggu, 01 Sep 2024 10:40 WIB    Nasional
# 28    Minggu, 01 Sep 2024 10:35 WIB    Nasional
# 29   Minggu, 01 Sep 2024 10:30 WIB      Ekonomi
# 30   Minggu, 01 Sep 2024 10:00 WIB      Ekonomi
# 31   Minggu, 01 Sep 2024 10:00 WIB      Ekonomi
# 32   Minggu, 01 Sep 2024 10:00 WIB      Edukasi
# 33   Minggu, 01 Sep 2024 09:50 WIB     Nasional
# 34   Minggu, 01 Sep 2024 09:50 WIB     Otomotif
# 35   Minggu, 01 Sep 2024 09:42 WIB     Olahraga
# 36   Minggu, 01 Sep 2024 09:33 WIB     Nasional
# 37   Minggu, 01 Sep 2024 09:30 WIB      Ekonomi
# 38   Minggu, 01 Sep 2024 09:20 WIB   Gaya Hidup
# 39   Minggu, 01 Sep 2024 09:15 WIB     Olahraga
# 40   Minggu, 01 Sep 2024 09:42 WIB     Olahraga
# 41   Minggu, 01 Sep 2024 09:33 WIB     Nasional
# 42   Minggu, 01 Sep 2024 09:30 WIB      Ekonomi
# 43   Minggu, 01 Sep 2024 09:20 WIB   Gaya Hidup
# 44   Minggu, 01 Sep 2024 09:15 WIB     Olahraga
# 45   Minggu, 01 Sep 2024 09:10 WIB      Ekonomi
# 46   Minggu, 01 Sep 2024 09:05 WIB     Nasional
# 47    Minggu, 01 Sep 2024 09:01 WIB   Teknologi
# 48   Minggu, 01 Sep 2024 09:00 WIB      Ekonomi
# 49   Minggu, 01 Sep 2024 08:57 WIB      Ekonomi
